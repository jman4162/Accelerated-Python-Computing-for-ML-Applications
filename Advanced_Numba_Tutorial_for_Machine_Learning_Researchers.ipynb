# %% [markdown]
# <a href="https://colab.research.google.com/github/jman4162/Accelerated-Python-Computing-for-ML-Applications/blob/main/Advanced_Numba_Tutorial_for_Machine_Learning_Researchers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Numba Tutorial for Machine Learning Researchers
#
# Name: John Hodge
#
# Date: 10/09/24
#
# # Advanced Numba Tutorial for Machine Learning Researchers
#
# ## Overview
#
# This advanced tutorial explores Numba, a powerful just-in-time (JIT) compiler for Python, tailored specifically for machine learning researchers. We'll delve into techniques to accelerate common ML tasks, covering basic JIT compilation, parallel processing, custom data types, GPU acceleration, and profiling. By the end, you'll be equipped to significantly optimize your Python code for machine learning applications.
#
# ## Introduction
#
# In the fast-paced world of machine learning, computational efficiency is crucial. As datasets expand and models grow more complex, researchers often encounter performance bottlenecks that hinder experimentation and model development. Numba addresses this challenge by compiling Python code to native machine instructions, dramatically speeding up numerical and scientific computations without the need for low-level language rewrites.
#
# This tutorial is designed for ML researchers familiar with Python and NumPy who want to elevate their code optimization skills. We'll explore how Numba can accelerate common machine learning tasks and algorithms, potentially reducing execution times from hours to minutes.
#
# Key topics include:
#
# 1. Basic JIT compilation
# 2. Parallel processing for multi-core CPUs
# 3. Custom data types for complex algorithms
# 4. GPU acceleration for massively parallel computations
# 5. Profiling and optimization techniques
#
# While Numba is powerful, it's not a universal solution. We'll discuss best practices, common pitfalls, and when to use Numba versus other optimization methods. By the end, you'll be able to unlock the full potential of your Python code for machine learning, enabling faster prototyping, quicker iterations, and the ability to work with larger datasets on standard hardware.
#
# Let's begin our journey into the world of high-performance Python for machine learning!
#
# ## Prerequisites
#
# Before we begin, make sure you have the following libraries installed and import the necessary libraries:

# %%
# !pip install -q numba numpy matplotlib scikit-learn

# %%
import numba
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from time import time

# %% [markdown]
# ## 1. Basic JIT Compilation
#
# Let's start with a quick refresher on basic JIT compilation:

# %%
@numba.jit(nopython=True)
def euclidean_distance(x1, x2):
    return np.sqrt(np.sum((x1 - x2)**2))

# Test the function
x1 = np.array([1, 2, 3])
x2 = np.array([4, 5, 6])
print(f"Distance: {euclidean_distance(x1, x2)}")
# Out:
# Distance: 5.196152422706632

# %% [markdown]
# ## 2. Parallel Processing with Numba
#
# Numba allows for easy parallelization of computations. Let's implement a parallel K-means clustering algorithm:

# %%
@numba.jit(nopython=True, parallel=True)
def kmeans(X, k, max_iterations=100):
    n_samples, n_features = X.shape

    # Initialize centroids randomly
    centroids = X[np.random.choice(n_samples, k, replace=False)]

    for _ in range(max_iterations):
        # Assign points to nearest centroid
        labels = np.empty(n_samples, dtype=np.int64)
        for i in numba.prange(n_samples):
            min_dist = np.inf
            for j in range(k):
                dist = np.sum((X[i] - centroids[j])**2)
                if dist < min_dist:
                    min_dist = dist
                    labels[i] = j

        # Update centroids
        new_centroids = np.zeros((k, n_features))
        counts = np.zeros(k)
        for i in numba.prange(n_samples):
            new_centroids[labels[i]] += X[i]
            counts[labels[i]] += 1

        for i in range(k):
            if counts[i] > 0:
                new_centroids[i] /= counts[i]

        # Check for convergence
        if np.all(centroids == new_centroids):
            break

        centroids = new_centroids

    return labels, centroids

# Generate sample data
X, _ = make_classification(n_samples=10000, n_features=20, n_informative=3, n_redundant=10, n_classes=3, random_state=42)

# Run K-means
start_time = time()
labels, centroids = kmeans(X, k=3)
end_time = time()

print(f"K-means clustering completed in {end_time - start_time:.4f} seconds")
# Out:
# K-means clustering completed in 9.8693 seconds

# %% [markdown]
# ## 3. Custom Data Types with Numba
#
# Numba allows you to define custom data types, which can be useful for complex algorithms:

# %%
from numba import types
from numba.experimental import jitclass

spec = [
    ('value', types.float64[:]),
    ('gradient', types.float64[:])
]

@jitclass(spec)
class Parameter:
    def __init__(self, n_features):
        self.value = np.zeros(n_features)
        self.gradient = np.zeros(n_features)

    def update(self, learning_rate):
        self.value -= learning_rate * self.gradient
        self.gradient.fill(0)

@numba.jit(nopython=True)
def logistic_regression(X, y, learning_rate=0.01, n_iterations=1000):
    n_samples, n_features = X.shape
    weights = Parameter(n_features)
    bias = Parameter(1)

    for _ in range(n_iterations):
        for i in range(n_samples):
            z = 0.0
            for j in range(n_features):
                z += X[i, j] * weights.value[j]
            z += bias.value[0]
            y_pred = 1 / (1 + np.exp(-z))

            error = y_pred - y[i]
            for j in range(n_features):
                weights.gradient[j] += error * X[i, j]
            bias.gradient[0] += error

        weights.update(learning_rate)
        bias.update(learning_rate)

    return weights.value, bias.value[0]

# Generate sample data
X, y = make_classification(n_samples=10000, n_features=20, n_informative=2, n_redundant=10, n_classes=2, random_state=42)

# Run logistic regression
start_time = time()
weights, bias = logistic_regression(X, y)
end_time = time()

print(f"Logistic regression completed in {end_time - start_time:.4f} seconds")
# Out:
# Logistic regression completed in 1.5645 seconds

# %% [markdown]
# ## 4. GPU Acceleration with Numba
#
# Numba can also leverage CUDA-enabled GPUs for even faster computations. Here's an example of matrix multiplication on GPU:

# %%
# !nvidia-smi
# Out:
# Wed Oct  9 23:31:36 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from numba import cuda

@cuda.jit
def matrix_mul(A, B, C):
    i, j = cuda.grid(2)
    if i < C.shape[0] and j < C.shape[1]:
        tmp = 0.
        for k in range(A.shape[1]):
            tmp += A[i, k] * B[k, j]
        C[i, j] = tmp

# Generate sample matrices
A = np.random.rand(1000, 1000)
B = np.random.rand(1000, 1000)
C = np.zeros((1000, 1000))

# Configure the blocks
threadsperblock = (16, 16)
blockspergrid_x = (A.shape[0] + threadsperblock[0] - 1) // threadsperblock[0]
blockspergrid_y = (B.shape[1] + threadsperblock[1] - 1) // threadsperblock[1]
blockspergrid = (blockspergrid_x, blockspergrid_y)

# Run the kernel
start_time = time()
d_A = cuda.to_device(A)
d_B = cuda.to_device(B)
d_C = cuda.to_device(C)
matrix_mul[blockspergrid, threadsperblock](d_A, d_B, d_C)
cuda.synchronize()
C = d_C.copy_to_host()
end_time = time()

print(f"GPU matrix multiplication completed in {end_time - start_time:.4f} seconds")
# Out:
# GPU matrix multiplication completed in 1.8560 seconds

# %% [markdown]
# ## 5. Profiling and Optimization

# %%
import cProfile
import numba
import numpy as np

@numba.jit(nopython=True)
def complex_function(x, y):
    result = 0
    for i in range(x.shape[0]):
        for j in range(y.shape[0]):
            result += np.sin(x[i]) * np.cos(y[j])
    return result

x = np.random.rand(1000)
y = np.random.rand(1000)

cProfile.run('complex_function(x, y)')
# Out:
#          237932 function calls (222960 primitive calls) in 0.848 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1022(_find_and_load)
#        10    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1038(_gcd_import)
#       574    0.003    0.000    0.008    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:216(_lock_unlock_module)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:294(_module_repr)
#        83    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:404(parent)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(has_location)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:581(_module_repr_from_spec)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:902(_resolve_name)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:968(_sanity_check)
#         1    0.025    0.025    0.025    0.025 <ipython-input-8-3e096d390581>:5(complex_function)
#         3    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.010    0.010    0.849    0.849 <string>:1(<module>)
#         8    0.000    0.000    0.000    0.000 __init__.py:10(__getattr__)
#        10    0.000    0.000    0.001    0.000 __init__.py:108(import_module)
#       346    0.000    0.000    0.000    0.000 __init__.py:1455(debug)
#       346    0.000    0.000    0.000    0.000 __init__.py:1724(isEnabledFor)
#        16    0.000    0.000    0.000    0.000 __init__.py:290(__getattr__)
#         3    0.000    0.000    0.000    0.000 __init__.py:48(create_string_buffer)
#        60    0.000    0.000    0.000    0.000 __init__.py:509(cast)
#         1    0.000    0.000    0.000    0.000 __init__.py:513(string_at)
#         1    0.000    0.000    0.000    0.000 __init__.py:579(__missing__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:1039(__iter__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:836(keys)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:840(items)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:862(__init__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:865(__len__)
#         8    0.000    0.000    0.000    0.000 _collections_abc.py:885(__iter__)
#       108    0.000    0.000    0.001    0.000 _collections_abc.py:909(__iter__)
#      2000    0.001    0.000    0.001    0.000 _utils.py:13(is_used)
#      1093    0.001    0.000    0.029    0.000 _utils.py:16(register)
#      1051    0.024    0.000    0.026    0.000 _utils.py:24(deduplicate)
# 2775/1158    0.020    0.000    0.066    0.000 _utils.py:44(__str__)
# 2086/2081    0.003    0.000    0.024    0.000 _utils.py:54(get_reference)
#        22    0.000    0.000    0.000    0.000 _utils.py:64(set_metadata)
#       769    0.000    0.000    0.001    0.000 _utils.py:71(_stringify_metadata)
#        22    0.000    0.000    0.000    0.000 _utils.py:76(<listcomp>)
#        44    0.000    0.000    0.000    0.000 _utils.py:9(__init__)
#      2167    0.009    0.000    0.010    0.000 abc.py:117(__instancecheck__)
#       676    0.000    0.000    0.001    0.000 abc.py:121(__subclasscheck__)
#        76    0.000    0.000    0.000    0.000 abstract.py:115(__repr__)
#       131    0.000    0.000    0.000    0.000 abstract.py:118(__str__)
#  1028/773    0.001    0.000    0.002    0.000 abstract.py:121(__hash__)
# 1283/1273    0.032    0.000    0.033    0.000 abstract.py:124(__eq__)
#       103    0.000    0.000    0.000    0.000 abstract.py:127(__ne__)
#       196    0.000    0.000    0.000    0.000 abstract.py:158(is_precise)
#         6    0.000    0.000    0.000    0.000 abstract.py:20(_autoincr)
#         5    0.000    0.000    0.000    0.000 abstract.py:253(unify)
#         6    0.000    0.000    0.000    0.000 abstract.py:28(_on_type_disposal)
#         5    0.000    0.000    0.000    0.000 abstract.py:433(_literal_init)
#         6    0.000    0.000    0.000    0.000 abstract.py:439(literal_value)
#        16    0.000    0.000    0.000    0.000 abstract.py:443(literal_type)
#        46    0.000    0.000    0.001    0.000 abstract.py:49(_intern)
#        46    0.000    0.000    0.001    0.000 abstract.py:61(__call__)
#        46    0.000    0.000    0.000    0.000 abstract.py:93(__init__)
#      1707    0.000    0.000    0.000    0.000 abstract.py:96(key)
#         9    0.002    0.000    0.004    0.000 analysis.py:118(compute_dead_maps)
#       135    0.000    0.000    0.000    0.000 analysis.py:138(<genexpr>)
#        90    0.000    0.000    0.000    0.000 analysis.py:141(<genexpr>)
#        72    0.000    0.000    0.000    0.000 analysis.py:182(<genexpr>)
#         9    0.001    0.000    0.002    0.000 analysis.py:190(compute_live_variables)
#        29    0.000    0.000    0.000    0.000 analysis.py:200(fix_point_progress)
#        10    0.004    0.000    0.026    0.003 analysis.py:23(compute_use_defs)
#        24    0.001    0.000    0.003    0.000 analysis.py:235(compute_cfg_from_blocks)
#         2    0.000    0.000    0.001    0.000 analysis.py:291(dead_branch_prune)
#         2    0.000    0.000    0.000    0.000 analysis.py:304(find_branches)
#         2    0.000    0.000    0.000    0.000 analysis.py:375(Unknown)
#       566    0.000    0.000    0.000    0.000 analysis.py:40(<genexpr>)
#         2    0.000    0.000    0.000    0.000 analysis.py:487(<listcomp>)
#         1    0.000    0.000    0.000    0.000 analysis.py:580(rewrite_semantic_constants)
#         9    0.000    0.000    0.003    0.000 analysis.py:60(compute_live_map)
#        23    0.000    0.000    0.000    0.000 analysis.py:607(rewrite_array_ndim)
#        23    0.000    0.000    0.000    0.000 analysis.py:617(rewrite_tuple_len)
#         1    0.000    0.000    0.000    0.000 analysis.py:651(find_literally_calls)
#        99    0.000    0.000    0.001    0.000 analysis.py:66(fix_point_progress)
#       729    0.000    0.000    0.000    0.000 analysis.py:69(<genexpr>)
#         1    0.000    0.000    0.000    0.000 analysis.py:702(must_use_alloca)
#        18    0.000    0.000    0.003    0.000 analysis.py:71(fix_point)
#        36    0.001    0.000    0.001    0.000 analysis.py:81(def_reach)
#        45    0.001    0.000    0.001    0.000 analysis.py:91(liveness)
#        32    0.000    0.000    0.010    0.000 api.py:194(typeof)
#        18    0.010    0.001    0.010    0.001 api.py:954(_builtin_function_type)
#         1    0.000    0.000    0.000    0.000 array_exprs.py:26(__init__)
#         7    0.000    0.000    0.000    0.000 array_exprs.py:33(match)
#        10    0.000    0.000    0.000    0.000 arraydecl.py:211(generic)
#        10    0.000    0.000    0.000    0.000 arraydecl.py:23(get_array_index_type)
#        12    0.000    0.000    0.000    0.000 arraydecl.py:302(resolve_shape)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:131(load_item)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:148(fix_integer_index)
#         2    0.000    0.000    0.003    0.001 arrayobj.py:2762(array_shape)
#         2    0.000    0.000    0.013    0.007 arrayobj.py:375(basic_indexing)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:392(<listcomp>)
#         6    0.000    0.000    0.000    0.000 arrayobj.py:44(set_range_metadata)
#         2    0.000    0.000    0.014    0.007 arrayobj.py:459(_getitem_array_generic)
#         2    0.000    0.000    0.016    0.008 arrayobj.py:480(getitem_arraynd_intp)
#         6    0.000    0.000    0.000    0.000 arrayobj.py:55(mark_positive)
#         6    0.000    0.000    0.000    0.000 arrayobj.py:63(make_array)
#         6    0.000    0.000    0.000    0.000 arrayobj.py:75(ArrayStruct)
#         6    0.000    0.000    0.013    0.002 arrayobj.py:77(_make_refs)
#         6    0.000    0.000    0.013    0.002 arrayobj.py:97(shape)
#         5    0.000    0.000    0.000    0.000 base.py:100(<lambda>)
#         2    0.000    0.000    0.000    0.000 base.py:1001(make_array)
#       124    0.000    0.000    0.012    0.000 base.py:103(_match_arglist)
#         5    0.000    0.000    0.006    0.001 base.py:1100(get_abi_sizeof)
#        14    0.000    0.000    0.000    0.000 base.py:1134(active_code_library)
#         2    0.000    0.000    0.000    0.000 base.py:1140(push_code_library)
#        14    0.000    0.000    0.000    0.000 base.py:1150(add_linking_libs)
#        14    0.000    0.000    0.002    0.000 base.py:1183(__init__)
#        14    0.000    0.000    0.098    0.007 base.py:1189(__call__)
#        14    0.000    0.000    0.000    0.000 base.py:1194(__getattr__)
#        14    0.000    0.000    0.001    0.000 base.py:1200(_has_loc)
#        14    0.000    0.000    0.000    0.000 base.py:1209(__init__)
#        14    0.000    0.000    0.002    0.000 base.py:1212(__call__)
#        14    0.000    0.000    0.097    0.007 base.py:1218(wrapper)
#       144    0.000    0.000    0.012    0.000 base.py:123(_match)
#       462    0.000    0.000    0.016    0.000 base.py:1246(enter_fn)
#       462    0.000    0.000    0.010    0.000 base.py:1249(exit_fn)
#       106    0.000    0.000    0.000    0.000 base.py:138(append)
#         2    0.000    0.000    0.000    0.000 base.py:191(enable_boundscheck)
#         7    0.000    0.000    0.011    0.002 base.py:261(refresh)
#         2    0.000    0.000    0.001    0.000 base.py:284(mangler)
#         3    0.000    0.000    0.000    0.000 base.py:290(get_env_name)
#         2    0.000    0.000    0.000    0.000 base.py:298(declare_env_global)
#         7    0.000    0.000    0.001    0.000 base.py:319(get_arg_packer)
#         1    0.000    0.000    0.000    0.000 base.py:329(nonconst_module_attrs)
#         1    0.000    0.000    0.000    0.000 base.py:336(nrt)
#         2    0.000    0.000    0.000    0.000 base.py:341(subtarget)
#        56    0.000    0.000    0.002    0.000 base.py:352(install_registry)
#        56    0.000    0.000    0.000    0.000 base.py:368(insert_func_defn)
#         5    0.000    0.000    0.000    0.000 base.py:37(__init__)
#        56    0.000    0.000    0.001    0.000 base.py:372(_insert_getattr_defn)
#        56    0.000    0.000    0.000    0.000 base.py:376(_insert_setattr_defn)
#        56    0.000    0.000    0.000    0.000 base.py:380(_insert_cast_defn)
#        56    0.000    0.000    0.000    0.000 base.py:384(_insert_get_constant_defn)
#         1    0.000    0.000    0.000    0.000 base.py:388(insert_user_function)
#         1    0.000    0.000    0.011    0.011 base.py:412(declare_function)
#        54    0.000    0.000    0.013    0.000 base.py:42(find)
#         9    0.000    0.000    0.003    0.000 base.py:431(insert_const_string)
#        12    0.000    0.000    0.002    0.000 base.py:451(insert_unique_const)
#         5    0.000    0.000    0.000    0.000 base.py:463(get_argument_type)
#         4    0.000    0.000    0.000    0.000 base.py:469(get_data_type)
#        49    0.000    0.000    0.001    0.000 base.py:479(get_value_type)
#        16    0.000    0.000    0.013    0.001 base.py:49(_find)
#         2    0.000    0.000    0.000    0.000 base.py:491(unpack_value)
#        24    0.000    0.000    0.001    0.000 base.py:500(get_constant_generic)
#        16    0.000    0.000    0.000    0.000 base.py:510(get_constant)
#     26/20    0.001    0.000    0.014    0.001 base.py:526(get_function)
#        16    0.000    0.000    0.012    0.001 base.py:56(_select_compatible)
#         4    0.000    0.000    0.000    0.000 base.py:576(get_getattr)
#         2    0.000    0.000    0.000    0.000 base.py:652(get_returned_value)
#         1    0.000    0.000    0.000    0.000 base.py:658(get_return_value)
#         4    0.000    0.000    0.000    0.000 base.py:66(_best_signature)
#         2    0.000    0.000    0.001    0.000 base.py:675(pair_first)
#         2    0.000    0.000    0.001    0.000 base.py:682(pair_second)
#     53/52    0.000    0.000    0.013    0.000 base.py:689(cast)
#         2    0.000    0.000    0.000    0.000 base.py:74(<lambda>)
#        10    0.000    0.000    0.003    0.000 base.py:746(get_c_value)
#         1    0.000    0.000    0.000    0.000 base.py:796(get_struct_type)
#         1    0.000    0.000    0.000    0.000 base.py:800(<listcomp>)
#         6    0.000    0.000    0.000    0.000 base.py:803(get_dummy_value)
#         6    0.000    0.000    0.000    0.000 base.py:806(get_dummy_type)
#         4    0.000    0.000    0.000    0.000 base.py:83(_sort_signatures)
#         4    0.000    0.000    0.000    0.000 base.py:954(get_python_api)
#         6    0.000    0.000    0.000    0.000 base.py:975(get_helper_class)
#         6    0.000    0.000    0.001    0.000 base.py:983(_make_helper)
#         6    0.000    0.000    0.001    0.000 base.py:987(make_helper)
#         1    0.000    0.000    0.000    0.000 base64.py:51(b64encode)
#         2    0.000    0.000    0.012    0.006 boxing.py:474(unbox_array)
#         1    0.000    0.000    0.000    0.000 boxing.py:65(box_float)
#        12    0.000    0.000    0.000    0.000 builder.py:160(wrapped)
#        58    0.000    0.000    0.000    0.000 builder.py:173(_label_suffix)
#         3    0.000    0.000    0.000    0.000 builder.py:190(__init__)
#      1219    0.000    0.000    0.000    0.000 builder.py:195(block)
#       132    0.000    0.000    0.000    0.000 builder.py:204(function)
#        23    0.000    0.000    0.000    0.000 builder.py:211(module)
#         5    0.000    0.000    0.000    0.000 builder.py:218(position_before)
#       165    0.000    0.000    0.000    0.000 builder.py:241(position_at_end)
#        67    0.000    0.000    0.023    0.000 builder.py:248(append_basic_block)
#       100    0.039    0.000    0.039    0.000 builder.py:264(goto_block)
#        86    0.000    0.000    0.040    0.000 builder.py:281(goto_entry_block)
#        62    0.000    0.000    0.000    0.000 builder.py:290(_branch_helper)
#        46    0.000    0.000    0.008    0.000 builder.py:297(if_then)
#        33    0.000    0.000    0.001    0.000 builder.py:31(wrapped)
#         8    0.000    0.000    0.000    0.000 builder.py:320(if_else)
#       783    0.001    0.000    0.001    0.000 builder.py:351(_insert)
#        79    0.000    0.000    0.000    0.000 builder.py:357(_set_terminator)
#         2    0.000    0.000    0.000    0.000 builder.py:539(not_)
#         2    0.000    0.000    0.000    0.000 builder.py:550(neg)
#        38    0.000    0.000    0.001    0.000 builder.py:568(_icmp)
#        24    0.000    0.000    0.001    0.000 builder.py:579(icmp_signed)
#        14    0.000    0.000    0.000    0.000 builder.py:588(icmp_unsigned)
#         8    0.000    0.000    0.000    0.000 builder.py:629(select)
#        45    0.000    0.000    0.001    0.000 builder.py:738(alloca)
#       115    0.000    0.000    0.010    0.000 builder.py:756(load)
#       134    0.001    0.000    0.003    0.000 builder.py:769(store)
#        36    0.000    0.000    0.001    0.000 builder.py:826(branch)
#        31    0.000    0.000    0.001    0.000 builder.py:834(cbranch)
#        12    0.000    0.000    0.000    0.000 builder.py:858(ret)
#        45    0.000    0.000    0.003    0.000 builder.py:875(call)
#        64    0.000    0.000    0.013    0.000 builder.py:922(gep)
#       182    0.001    0.000    0.016    0.000 builder.py:967(extract_value)
#        24    0.000    0.000    0.001    0.000 builder.py:977(insert_value)
#         4    0.000    0.000    0.000    0.000 builder.py:989(phi)
#         8    0.000    0.000    0.000    0.000 builtins.py:106(generic)
#         4    0.000    0.000    0.000    0.000 builtins.py:358(constant_dummy)
#        20    0.000    0.000    0.000    0.000 builtins.py:544(generic)
#         8    0.000    0.000    0.000    0.000 builtins.py:605(generic)
#         8    0.000    0.000    0.000    0.000 builtins.py:95(generic)
#        41    0.000    0.000    0.000    0.000 bytecode.py:139(__repr__)
#        41    0.000    0.000    0.000    0.000 bytecode.py:163(_unpack_opargs)
#        42    0.000    0.000    0.000    0.000 bytecode.py:219(_patched_opargs)
#         1    0.000    0.000    0.000    0.000 bytecode.py:235(__init__)
#         1    0.000    0.000    0.000    0.000 bytecode.py:239(__iter__)
#        42    0.000    0.000    0.000    0.000 bytecode.py:242(_fetch_opcode)
#        42    0.000    0.000    0.000    0.000 bytecode.py:245(next)
#         1    0.000    0.000    0.001    0.001 bytecode.py:268(__init__)
#         5    0.000    0.000    0.000    0.000 bytecode.py:271(<genexpr>)
#         1    0.000    0.000    0.000    0.000 bytecode.py:288(_compute_lineno)
#       190    0.000    0.000    0.000    0.000 bytecode.py:310(__getitem__)
#         1    0.000    0.000    0.000    0.000 bytecode.py:316(dump)
#        41    0.000    0.000    0.000    0.000 bytecode.py:317(label_marker)
#         1    0.000    0.000    0.000    0.000 bytecode.py:32(get_function_object)
#        42    0.000    0.000    0.000    0.000 bytecode.py:323(<genexpr>)
#         1    0.000    0.000    0.000    0.000 bytecode.py:44(get_code_object)
#         1    0.000    0.000    0.000    0.000 bytecode.py:549(from_function)
#        41    0.000    0.000    0.000    0.000 bytecode.py:81(__init__)
#         8    0.000    0.000    0.000    0.000 bytecode.py:89(is_jump)
#         8    0.000    0.000    0.000    0.000 bytecode.py:97(get_jump_target)
#         4    0.000    0.000    0.000    0.000 byteflow.py:1099(op_BINARY_SUBSCR)
#         4    0.000    0.000    0.000    0.000 byteflow.py:1136(op_CALL_FUNCTION)
#         4    0.000    0.000    0.000    0.000 byteflow.py:1138(<listcomp>)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1392(op_GET_ITER)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1398(op_FOR_ITER)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1449(_binaryop)
#         7    0.000    0.000    0.000    0.000 byteflow.py:148(<lambda>)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1591(op_LOAD_METHOD)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1596(op_CALL_METHOD)
#         9    0.000    0.000    0.000    0.000 byteflow.py:1604(__init__)
#        83    0.000    0.000    0.000    0.000 byteflow.py:1644(get_identity)
#        79    0.000    0.000    0.000    0.000 byteflow.py:1647(__hash__)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1653(__eq__)
#        36    0.000    0.000    0.000    0.000 byteflow.py:1656(pc_initial)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1663(instructions)
#        14    0.000    0.000    0.000    0.000 byteflow.py:1670(outgoing_edges)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1680(outgoing_phis)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1689(blockstack_initial)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1705(find_initial_try_block)
#        41    0.000    0.000    0.000    0.000 byteflow.py:1712(has_terminated)
#       142    0.000    0.000    0.000    0.000 byteflow.py:1715(get_inst)
#        36    0.000    0.000    0.000    0.000 byteflow.py:1718(advance_pc)
#        50    0.000    0.000    0.000    0.000 byteflow.py:1722(make_temp)
#        41    0.000    0.000    0.000    0.000 byteflow.py:1740(append)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1745(get_tos)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1748(peek)
#        45    0.000    0.000    0.000    0.000 byteflow.py:1753(push)
#        31    0.000    0.000    0.000    0.000 byteflow.py:1757(pop)
#        36    0.000    0.000    0.000    0.000 byteflow.py:1809(get_top_block)
#        36    0.000    0.000    0.000    0.000 byteflow.py:181(_run_handle_exception)
#        36    0.000    0.000    0.000    0.000 byteflow.py:1825(has_active_try)
#         8    0.000    0.000    0.000    0.000 byteflow.py:1830(get_varname)
#         9    0.000    0.000    0.000    0.000 byteflow.py:1835(terminate)
#         8    0.000    0.000    0.000    0.000 byteflow.py:1840(fork)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1877(split_new_block)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1882(get_outgoing_states)
#         8    0.000    0.000    0.000    0.000 byteflow.py:1891(<listcomp>)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1899(get_outgoing_edgepushed)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1908(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1957(__init__)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1960(infos)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1972(adapt_state_infos)
#   120/112    0.000    0.000    0.000    0.000 byteflow.py:1982(_flatten_inst_regs)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1996(__init__)
#        44    0.000    0.000    0.000    0.000 byteflow.py:2019(backbone)
#        10    0.000    0.000    0.000    0.000 byteflow.py:2023(blocks)
#         8    0.000    0.000    0.000    0.000 byteflow.py:2027(iterliveblocks)
#         7    0.000    0.000    0.000    0.000 byteflow.py:2036(__init__)
#        48    0.000    0.000    0.000    0.000 byteflow.py:2038(<genexpr>)
#         1    0.000    0.000    0.000    0.000 byteflow.py:205(_build_cfg)
#         1    0.000    0.000    0.000    0.000 byteflow.py:217(_prune_phis)
#         1    0.000    0.000    0.000    0.000 byteflow.py:225(get_used_phis_per_state)
#         1    0.000    0.000    0.000    0.000 byteflow.py:236(find_use_defs)
#         1    0.000    0.000    0.000    0.000 byteflow.py:249(propagate_phi_map)
#         1    0.000    0.000    0.000    0.000 byteflow.py:271(apply_changes)
#        36    0.000    0.000    0.000    0.000 byteflow.py:294(_is_implicit_new_block)
#         2    0.000    0.000    0.000    0.000 byteflow.py:304(_guard_with_as)
#        12    0.000    0.000    0.000    0.000 byteflow.py:318(_is_null_temp_reg)
#         1    0.000    0.000    0.000    0.000 byteflow.py:325(__init__)
#        41    0.000    0.000    0.001    0.000 byteflow.py:333(dispatch)
#         1    0.000    0.000    0.000    0.000 byteflow.py:379(op_NOP)
#         4    0.000    0.000    0.000    0.000 byteflow.py:455(op_LOAD_GLOBAL)
#         3    0.000    0.000    0.000    0.000 byteflow.py:473(op_LOAD_CONST)
#         4    0.000    0.000    0.000    0.000 byteflow.py:478(op_LOAD_ATTR)
#         8    0.000    0.000    0.000    0.000 byteflow.py:491(op_LOAD_FAST)
#        36    0.000    0.000    0.000    0.000 byteflow.py:52(__init__)
#         4    0.000    0.000    0.000    0.000 byteflow.py:521(op_STORE_FAST)
#         8    0.000    0.000    0.000    0.000 byteflow.py:76(__init__)
#         2    0.000    0.000    0.000    0.000 byteflow.py:856(op_JUMP_ABSOLUTE)
#         1    0.000    0.000    0.000    0.000 byteflow.py:867(op_RETURN_VALUE)
#         1    0.000    0.000    0.000    0.000 byteflow.py:89(__init__)
#         1    0.000    0.000    0.003    0.003 byteflow.py:94(run)
#         1    0.000    0.000    0.000    0.000 caching.py:82(load_overload)
#         1    0.000    0.000    0.000    0.000 caching.py:85(save_overload)
#         3    0.000    0.000    0.000    0.000 callconv.py:101(get_return_type)
#         1    0.000    0.000    0.000    0.000 callconv.py:108(init_call_helper)
#         2    0.000    0.000    0.008    0.004 callconv.py:122(raise_error)
#         1    0.000    0.000    0.001    0.001 callconv.py:152(decode_arguments)
#         7    0.000    0.000    0.001    0.000 callconv.py:161(_get_arg_packer)
#         1    0.000    0.000    0.000    0.000 callconv.py:370(_make_call_helper)
#         1    0.000    0.000    0.000    0.000 callconv.py:373(return_value)
#         2    0.000    0.000    0.000    0.000 callconv.py:380(build_excinfo_struct)
#         2    0.000    0.000    0.001    0.000 callconv.py:397(set_static_user_exc)
#         2    0.000    0.000    0.001    0.001 callconv.py:454(return_user_exc)
#         2    0.000    0.000    0.004    0.002 callconv.py:468(unpack_dynamic_exception)
#         2    0.000    0.000    0.006    0.003 callconv.py:520(unpack_exception)
#        16    0.000    0.000    0.000    0.000 callconv.py:60(__init__)
#         2    0.000    0.000    0.000    0.000 callconv.py:726(_get_try_state)
#         2    0.000    0.000    0.000    0.000 callconv.py:736(check_try_status)
#         3    0.000    0.000    0.000    0.000 callconv.py:774(_return_errcode_raw)
#         2    0.000    0.000    0.001    0.000 callconv.py:777(_get_return_status)
#         3    0.000    0.000    0.001    0.000 callconv.py:801(get_function_type)
#         1    0.000    0.000    0.000    0.000 callconv.py:813(decorate_function)
#         1    0.000    0.000    0.000    0.000 callconv.py:819(<listcomp>)
#         2    0.000    0.000    0.000    0.000 callconv.py:838(type_may_always_need_nrt)
#         2    0.000    0.000    0.000    0.000 callconv.py:856(get_arguments)
#         4    0.000    0.000    0.000    0.000 callconv.py:862(_get_return_argument)
#         5    0.000    0.000    0.000    0.000 callconv.py:865(_get_excinfo_argument)
#         2    0.004    0.002    0.008    0.004 callconv.py:868(call_function)
#         3    0.000    0.000    0.000    0.000 callconv.py:912(__init__)
#         3    0.000    0.000    0.000    0.000 callconv.py:952(create_error_model)
#         1    0.000    0.000    0.034    0.034 callwrapper.py:101(build)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:11(__init__)
#         1    0.000    0.000    0.030    0.030 callwrapper.py:126(build_wrapper)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:129(<listcomp>)
#         1    0.000    0.000    0.004    0.004 callwrapper.py:197(get_env)
#         2    0.000    0.000    0.014    0.007 callwrapper.py:20(add_arg)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:212(_simplified_return_type)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:224(debug_print)
#         4    0.000    0.000    0.004    0.001 callwrapper.py:38(cleanup_arg)
#         1    0.000    0.000    0.002    0.002 callwrapper.py:66(emit_cleanup)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:92(__init__)
#        32    0.000    0.000    0.000    0.000 cffi_utils.py:29(is_ffi_instance)
#        32    0.000    0.000    0.010    0.000 cffi_utils.py:39(is_cffi_func)
#         8    0.000    0.000    0.000    0.000 cgutils.py:1184(normalize_ir_text)
#         2    0.000    0.000    0.000    0.000 cgutils.py:1216(is_nonelike)
#        20    0.000    0.000    0.042    0.002 cgutils.py:124(_make_refs)
#        56    0.000    0.000    0.003    0.000 cgutils.py:142(_get_ptr_by_index)
#         6    0.000    0.000    0.000    0.000 cgutils.py:145(_get_ptr_by_name)
#        32    0.000    0.000    0.011    0.000 cgutils.py:149(__getattr__)
#       138    0.000    0.000    0.002    0.000 cgutils.py:158(__setattr__)
#        32    0.000    0.000    0.011    0.000 cgutils.py:166(__getitem__)
#        18    0.000    0.000    0.002    0.000 cgutils.py:173(__setitem__)
#         2    0.000    0.000    0.000    0.000 cgutils.py:202(_getpointer)
#         6    0.000    0.000    0.000    0.000 cgutils.py:208(_getvalue)
#        20    0.000    0.000    0.000    0.000 cgutils.py:228(_get_be_type)
#        32    0.000    0.000    0.000    0.000 cgutils.py:231(_cast_member_to_value)
#        18    0.000    0.000    0.000    0.000 cgutils.py:234(_cast_member_from_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:261(__init__)
#         7    0.000    0.000    0.000    0.000 cgutils.py:308(__setattr__)
#        43    0.000    0.000    0.044    0.001 cgutils.py:362(alloca_once)
#        40    0.003    0.000    0.017    0.000 cgutils.py:417(get_or_insert_function)
#        19    0.000    0.000    0.005    0.000 cgutils.py:435(add_global_variable)
#        11    0.000    0.000    0.000    0.000 cgutils.py:44(make_bytearray)
#         2    0.000    0.000    0.000    0.000 cgutils.py:440(terminate)
#        14    0.000    0.000    0.000    0.000 cgutils.py:446(get_null_value)
#         3    0.000    0.000    0.000    0.000 cgutils.py:450(is_null)
#         4    0.000    0.000    0.000    0.000 cgutils.py:455(is_not_null)
#         8    0.000    0.000    0.000    0.000 cgutils.py:460(if_unlikely)
#         2    0.000    0.000    0.000    0.000 cgutils.py:464(if_likely)
#         2    0.000    0.000    0.000    0.000 cgutils.py:472(increment_index)
#         4    0.000    0.000    0.023    0.006 cgutils.py:486(for_range)
#        12    0.000    0.000    0.000    0.000 cgutils.py:56(create_struct_proxy)
#         4    0.000    0.000    0.023    0.006 cgutils.py:618(loop_nest)
#         4    0.000    0.000    0.000    0.000 cgutils.py:640(<lambda>)
#         4    0.000    0.000    0.023    0.006 cgutils.py:646(_loop_nest)
#         6    0.000    0.000    0.000    0.000 cgutils.py:656(pack_array)
#         8    0.000    0.000    0.000    0.000 cgutils.py:682(unpack_tuple)
#         8    0.000    0.000    0.000    0.000 cgutils.py:689(<listcomp>)
#         2    0.000    0.000    0.001    0.001 cgutils.py:694(get_item_pointer)
#         2    0.000    0.000    0.000    0.000 cgutils.py:736(get_item_pointer2)
#        21    0.000    0.000    0.000    0.000 cgutils.py:912(is_pointer)
#        62    0.000    0.000    0.014    0.000 cgutils.py:929(gep_inbounds)
#        62    0.000    0.000    0.014    0.000 cgutils.py:936(gep)
#         1    0.000    0.000    0.000    0.000 cgutils.py:955(pointer_add)
#        20    0.000    0.000    0.056    0.003 cgutils.py:99(__init__)
#        11    0.000    0.000    0.002    0.000 cgutils.py:993(global_constant)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:1042(_class_reduce)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:1260(dump)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:1270(__init__)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:1307(reducer_override)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:195(_is_registered_pickle_by_value)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:209(_whichmodule)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:242(_should_pickle_by_reference)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:278(_lookup_module_and_qualname)
#         1    0.000    0.000    0.001    0.001 codegen.py:1013(scan_unresolved_symbols)
#         1    0.000    0.000    0.001    0.001 codegen.py:1032(scan_defined_symbols)
#         1    0.000    0.000    0.000    0.000 codegen.py:1040(resolve)
#         1    0.000    0.000    0.000    0.000 codegen.py:1045(<listcomp>)
#         3    0.000    0.000    0.024    0.008 codegen.py:1058(wrapper)
#         1    0.000    0.000    0.000    0.000 codegen.py:1082(is_symbol_defined)
#         1    0.000    0.000    0.007    0.007 codegen.py:1087(_load_defined_symbols)
#         2    0.000    0.000    0.007    0.003 codegen.py:1091(<setcomp>)
#         1    0.000    0.000    0.007    0.007 codegen.py:1094(add_module)
#         5    0.000    0.000    0.000    0.000 codegen.py:1143(target_data)
#         1    0.000    0.000    0.015    0.015 codegen.py:1150(create_library)
#         4    0.000    0.000    0.015    0.004 codegen.py:1220(_create_empty_module)
#         3    0.000    0.000    0.012    0.004 codegen.py:1248(_function_pass_manager)
#         3    0.000    0.000    0.001    0.000 codegen.py:1258(_pass_manager_builder)
#         1    0.000    0.000    0.000    0.000 codegen.py:1278(_check_llvm_bugs)
#         1    0.000    0.000    0.002    0.002 codegen.py:1315(_scan_and_fix_unresolved_refs)
#         1    0.000    0.000    0.007    0.007 codegen.py:1412(_add_module)
#         1    0.000    0.000    0.000    0.000 codegen.py:1420(set_env)
#         3    0.000    0.000    0.000    0.000 codegen.py:32(_parse_refprune_flags)
#         1    0.000    0.000    0.000    0.000 codegen.py:529(__init__)
#         1    0.000    0.000    0.000    0.000 codegen.py:542(recorded_timings)
#         1    0.000    0.000    0.000    0.000 codegen.py:546(codegen)
#         2    0.000    0.000    0.000    0.000 codegen.py:553(name)
#         5    0.000    0.000    0.000    0.000 codegen.py:560(_raise_if_finalized)
#       3/2    0.000    0.000    0.155    0.078 codegen.py:565(_ensure_finalized)
#         1    0.000    0.000    0.000    0.000 codegen.py:569(create_ir_module)
#         1    0.000    0.000    0.000    0.000 codegen.py:620(enable_object_caching)
#         1    0.000    0.000    0.015    0.015 codegen.py:643(__init__)
#         3    0.000    0.000    0.051    0.017 codegen.py:651(_optimize_functions)
#         1    0.000    0.000    0.114    0.114 codegen.py:667(_optimize_final_module)
#         1    0.000    0.000    0.000    0.000 codegen.py:684(_get_module_for_linking)
#         1    0.000    0.000    0.000    0.000 codegen.py:719(add_linking_library)
#         3    0.000    0.000    0.148    0.049 codegen.py:723(add_ir_module)
#         3    0.000    0.000    0.052    0.017 codegen.py:732(add_llvm_module)
#         1    0.000    0.000    0.155    0.155 codegen.py:739(finalize)
#         1    0.000    0.000    0.004    0.004 codegen.py:767(_finalize_dynamic_globals)
#         1    0.000    0.000    0.003    0.003 codegen.py:773(_verify_declare_only_symbols)
#         1    0.000    0.000    0.040    0.040 codegen.py:781(_finalize_final_module)
#         1    0.000    0.000    0.000    0.000 codegen.py:880(_object_compiled_hook)
#         1    0.000    0.000    0.000    0.000 codegen.py:893(_object_getbuffer_hook)
#         1    0.000    0.000    0.156    0.156 codegen.py:975(get_pointer_to_function)
#         1    0.000    0.000    0.026    0.026 codegen.py:996(_finalize_specific)
#        20    0.000    0.000    0.000    0.000 collections.py:43(generic)
#         8    0.000    0.000    0.000    0.000 common.py:21(iterator_type)
#       159    0.000    0.000    0.000    0.000 common.py:27(_is_shutting_down)
#         8    0.000    0.000    0.000    0.000 common.py:32(yield_type)
#        22    0.000    0.000    0.000    0.000 common.py:4(_encode_string)
#         3    0.000    0.000    0.000    0.000 common.py:49(__init__)
#         6    0.000    0.000    0.000    0.000 common.py:76(as_array)
#        75    0.010    0.000    0.010    0.000 common.py:9(_decode_string)
#         1    0.000    0.000    0.000    0.000 compiler.py:278(sanitize_compile_result_entries)
#         1    0.000    0.000    0.000    0.000 compiler.py:294(compile_result)
#         1    0.000    0.000    0.000    0.000 compiler.py:328(__init__)
#       542    0.000    0.000    0.000    0.000 compiler.py:354(__getattr__)
#        33    0.000    0.000    0.000    0.000 compiler.py:360(__setattr__)
#         1    0.000    0.000    0.000    0.000 compiler.py:364(_make_subtarget)
#         1    0.000    0.000    0.003    0.003 compiler.py:390(__init__)
#         1    0.000    0.000    0.810    0.810 compiler.py:432(compile_extra)
#         1    0.000    0.000    0.809    0.809 compiler.py:455(_compile_core)
#         1    0.000    0.000    0.809    0.809 compiler.py:501(_compile_bytecode)
#         1    0.000    0.000    0.001    0.001 compiler.py:520(define_pipelines)
#         1    0.000    0.000    0.001    0.001 compiler.py:540(define_nopython_pipeline)
#         1    0.000    0.000    0.000    0.000 compiler.py:559(define_nopython_lowering_pipeline)
#         1    0.000    0.000    0.000    0.000 compiler.py:599(define_typed_pipeline)
#         1    0.000    0.000    0.000    0.000 compiler.py:635(define_untyped_pipeline)
#         1    0.000    0.000    0.813    0.813 compiler.py:718(compile_extra)
#        34    0.000    0.000    0.001    0.000 compiler_lock.py:11(acquire)
#        34    0.000    0.000    0.001    0.000 compiler_lock.py:15(release)
#        34    0.001    0.000    0.001    0.000 compiler_lock.py:19(__enter__)
#        34    0.000    0.000    0.001    0.000 compiler_lock.py:22(__exit__)
#         1    0.000    0.000    0.000    0.000 compiler_lock.py:25(is_locked)
#     33/27    0.000    0.000    0.807    0.030 compiler_lock.py:32(_acquire_compile_lock)
#         1    0.000    0.000    0.000    0.000 compiler_lock.py:52(require_global_compiler_lock)
#         2    0.000    0.000    0.000    0.000 compiler_machinery.py:103(get_analysis)
#        52    0.000    0.000    0.000    0.000 compiler_machinery.py:139(__init__)
#        50    0.000    0.000    0.000    0.000 compiler_machinery.py:143(get_required_set)
#         8    0.000    0.000    0.000    0.000 compiler_machinery.py:149(add_required)
#         4    0.000    0.000    0.000    0.000 compiler_machinery.py:177(__init__)
#        26    0.000    0.000    0.000    0.000 compiler_machinery.py:188(_validate_pass)
#        26    0.000    0.000    0.000    0.000 compiler_machinery.py:201(add_pass)
#         4    0.000    0.000    0.000    0.000 compiler_machinery.py:227(_debug_init)
#        12    0.000    0.000    0.000    0.000 compiler_machinery.py:229(parse)
#        78    0.000    0.000    0.000    0.000 compiler_machinery.py:24(__enter__)
#         4    0.000    0.000    0.001    0.000 compiler_machinery.py:246(finalize)
#         1    0.000    0.000    0.000    0.000 compiler_machinery.py:256(finalized)
#        26    0.002    0.000    0.806    0.031 compiler_machinery.py:268(_runPass)
#        78    0.000    0.000    0.777    0.010 compiler_machinery.py:272(check)
#        78    0.000    0.000    0.000    0.000 compiler_machinery.py:28(__exit__)
#        52    0.000    0.000    0.000    0.000 compiler_machinery.py:280(debug_print)
#         1    0.000    0.000    0.808    0.808 compiler_machinery.py:342(run)
#         1    0.000    0.000    0.000    0.000 compiler_machinery.py:36(__init__)
#         4    0.000    0.000    0.000    0.000 compiler_machinery.py:370(dependency_analysis)
#        50    0.000    0.000    0.000    0.000 compiler_machinery.py:385(resolve_requires)
#         6    0.000    0.000    0.000    0.000 compiler_machinery.py:386(walk)
#       104    0.000    0.000    0.000    0.000 compiler_machinery.py:41(name)
#       104    0.000    0.000    0.000    0.000 compiler_machinery.py:429(is_registered)
#        78    0.000    0.000    0.000    0.000 compiler_machinery.py:432(get)
#        26    0.000    0.000    0.000    0.000 compiler_machinery.py:69(analysis)
#        26    0.000    0.000    0.000    0.000 compiler_machinery.py:76(run_initialization)
#        26    0.000    0.000    0.000    0.000 compiler_machinery.py:91(run_finalizer)
#        44    0.000    0.000    0.000    0.000 compiler_machinery.py:98(get_analysis_usage)
#         1    0.000    0.000    0.001    0.001 config.py:151(update)
#         1    0.000    0.000    0.000    0.000 config.py:184(validate)
#         1    0.000    0.000    0.001    0.001 config.py:604(reload_config)
#         2    0.000    0.000    0.000    0.000 consts.py:111(_infer_getattr)
#         1    0.000    0.000    0.000    0.000 consts.py:18(__init__)
#      10/8    0.000    0.000    0.001    0.000 consts.py:24(infer_constant)
#         2    0.000    0.000    0.000    0.000 consts.py:47(_fail)
#      10/8    0.000    0.000    0.001    0.000 consts.py:56(_do_infer)
#         4    0.000    0.000    0.000    0.000 consts.py:73(_infer_expr)
#         2    0.000    0.000    0.000    0.000 containers.py:220(__len__)
#         8    0.000    0.000    0.000    0.000 containers.py:223(types)
#        20    0.000    0.000    0.000    0.000 containers.py:233(__init__)
#       150    0.000    0.000    0.000    0.000 containers.py:243(key)
#         8    0.000    0.000    0.000    0.000 containers.py:256(__unliteral__)
#         8    0.000    0.000    0.000    0.000 containers.py:34(__init__)
#       100    0.000    0.000    0.000    0.000 containers.py:40(key)
#         1    0.000    0.000    0.000    0.000 context.py:108(__init__)
#        10    0.000    0.000    0.000    0.000 context.py:13(__init__)
#         5    0.000    0.000    0.000    0.000 context.py:135(__init__)
#         5    0.000    0.000    0.000    0.000 context.py:148(init)
#         8    0.000    0.000    0.003    0.000 context.py:153(refresh)
#        56    0.000    0.000    0.031    0.001 context.py:189(resolve_function_type)
#         9    0.000    0.000    0.000    0.000 context.py:21(_dispose)
#        24    0.000    0.000    0.001    0.000 context.py:217(_resolve_builtin_function_type)
#       104    0.000    0.000    0.000    0.000 context.py:22(__init__)
#         8    0.000    0.000    0.000    0.000 context.py:228(<listcomp>)
#        56    0.000    0.000    0.029    0.001 context.py:233(_resolve_user_function_type)
#       386    0.000    0.000    0.001    0.000 context.py:250(_get_attribute_templates)
#        52    0.000    0.000    0.016    0.000 context.py:263(resolve_getattr)
#        94    0.000    0.000    0.015    0.000 context.py:268(core)
#       104    0.000    0.000    0.000    0.000 context.py:27(astuple)
#        98    0.012    0.000    0.016    0.000 context.py:287(find_matching_getattr_template)
#         1    0.000    0.000    0.000    0.000 context.py:30(__init__)
#         8    0.000    0.000    0.001    0.000 context.py:317(resolve_static_getitem)
#        12    0.000    0.000    0.001    0.000 context.py:342(resolve_module_constants)
#    209/89    0.021    0.000    0.058    0.001 context.py:343(get_meminfos)
#        89    0.001    0.000    0.059    0.001 context.py:360(_call_incref_decref)
#        42    0.000    0.000    0.013    0.000 context.py:374(resolve_value_type)
#        31    0.000    0.000    0.032    0.001 context.py:378(incref)
#        58    0.000    0.000    0.027    0.000 context.py:384(decref)
#        91    0.000    0.000    0.000    0.000 context.py:40(_require_nrt)
#        34    0.000    0.000    0.000    0.000 context.py:408(_get_global_type)
#         8    0.000    0.000    0.001    0.000 context.py:415(_load_builtins)
#        72    0.001    0.000    0.002    0.000 context.py:428(install_registry)
#       114    0.000    0.000    0.000    0.000 context.py:443(is_for_this_target)
#         5    0.000    0.000    0.000    0.000 context.py:48(__init__)
#       102    0.000    0.000    0.000    0.000 context.py:499(_lookup_global)
#        12    0.000    0.000    0.000    0.000 context.py:513(_insert_global)
#       121    0.000    0.000    0.000    0.000 context.py:52(__getitem__)
#        12    0.000    0.000    0.000    0.000 context.py:538(insert_global)
#       100    0.000    0.000    0.000    0.000 context.py:541(insert_attributes)
#       184    0.000    0.000    0.001    0.000 context.py:561(can_convert)
#       104    0.001    0.000    0.002    0.000 context.py:586(_rate_arguments)
#       121    0.000    0.000    0.000    0.000 context.py:59(__len__)
#         2    0.000    0.000    0.000    0.000 context.py:62(register)
#        18    0.001    0.000    0.003    0.000 context.py:636(resolve_overload)
#       104    0.000    0.000    0.000    0.000 context.py:661(<lambda>)
#         1    0.000    0.000    0.000    0.000 context.py:683(unify_types)
#         1    0.000    0.000    0.000    0.000 context.py:686(keyfunc)
#       108    0.000    0.000    0.001    0.000 context.py:699(unify_pairs)
#         8    0.000    0.000    0.002    0.000 context.py:744(load_additional_registries)
#         2    0.000    0.000    0.000    0.000 context.py:75(free)
#         1    0.000    0.000    0.000    0.000 context.py:76(finditer)
#        10    0.000    0.000    0.001    0.000 context.py:8(get_global_context)
#         1    0.000    0.000    0.000    0.000 context.py:94(match)
#       760    0.002    0.000    0.002    0.000 contextlib.py:102(__init__)
#   760/684    0.001    0.000    0.091    0.000 contextlib.py:130(__enter__)
#   760/686    0.001    0.000    0.004    0.000 contextlib.py:139(__exit__)
#       760    0.001    0.000    0.003    0.000 contextlib.py:279(helper)
#         3    0.000    0.000    0.000    0.000 contextlib.py:442(_create_exit_wrapper)
#        28    0.000    0.000    0.000    0.000 contextlib.py:452(__init__)
#        27    0.000    0.000    0.000    0.000 contextlib.py:462(push)
#         3    0.000    0.000    0.000    0.000 contextlib.py:482(enter_context)
#         3    0.000    0.000    0.000    0.000 contextlib.py:509(_push_cm_exit)
#        30    0.000    0.000    0.000    0.000 contextlib.py:514(_push_exit_callback)
#        28    0.000    0.000    0.000    0.000 contextlib.py:530(__enter__)
#        28    0.000    0.000    0.001    0.000 contextlib.py:533(__exit__)
#       200    0.000    0.000    0.001    0.000 controlflow.py:103(add_edge)
#       975    0.002    0.000    0.002    0.000 controlflow.py:118(successors)
#       681    0.000    0.000    0.000    0.000 controlflow.py:126(predecessors)
#        25    0.000    0.000    0.000    0.000 controlflow.py:134(set_entry_point)
#        25    0.000    0.000    0.001    0.000 controlflow.py:141(process)
#         1    0.000    0.000    0.000    0.000 controlflow.py:151(dominators)
#         4    0.000    0.000    0.000    0.000 controlflow.py:170(immediate_dominators)
#         1    0.000    0.000    0.000    0.000 controlflow.py:179(dominance_frontier)
#         1    0.000    0.000    0.000    0.000 controlflow.py:199(_exit_points)
#         1    0.000    0.000    0.000    0.000 controlflow.py:203(_doms)
#        13    0.000    0.000    0.001    0.000 controlflow.py:207(_back_edges)
#         1    0.000    0.000    0.000    0.000 controlflow.py:211(_topo_order)
#        11    0.000    0.000    0.001    0.000 controlflow.py:219(_loops)
#         1    0.000    0.000    0.000    0.000 controlflow.py:223(_in_loops)
#         1    0.000    0.000    0.000    0.000 controlflow.py:227(_post_doms)
#         1    0.000    0.000    0.000    0.000 controlflow.py:231(_idom)
#         1    0.000    0.000    0.000    0.000 controlflow.py:235(_df)
#        13    0.000    0.000    0.000    0.000 controlflow.py:250(entry_point)
#         2    0.000    0.000    0.000    0.000 controlflow.py:263(backbone)
#        10    0.000    0.000    0.001    0.000 controlflow.py:272(loops)
#         7    0.000    0.000    0.000    0.000 controlflow.py:279(in_loops)
#         7    0.000    0.000    0.000    0.000 controlflow.py:284(<listcomp>)
#         2    0.000    0.000    0.000    0.000 controlflow.py:286(dead_nodes)
#         1    0.000    0.000    0.000    0.000 controlflow.py:305(topo_sort)
#       200    0.000    0.000    0.000    0.000 controlflow.py:368(_add_edge)
#         1    0.000    0.000    0.000    0.000 controlflow.py:375(_remove_node_edges)
#       200    0.000    0.000    0.001    0.000 controlflow.py:383(_dfs)
#        25    0.000    0.000    0.001    0.000 controlflow.py:396(_eliminate_dead_blocks)
#         1    0.000    0.000    0.000    0.000 controlflow.py:410(_find_exit_points)
#         1    0.000    0.000    0.000    0.000 controlflow.py:420(_find_postorder)
#         7    0.000    0.000    0.000    0.000 controlflow.py:429(dfs_rec)
#         1    0.000    0.000    0.000    0.000 controlflow.py:444(_find_immediate_dominators)
#         2    0.000    0.000    0.000    0.000 controlflow.py:454(intersect)
#         1    0.000    0.000    0.000    0.000 controlflow.py:466(<dictcomp>)
#        26    0.000    0.000    0.000    0.000 controlflow.py:476(<genexpr>)
#         1    0.000    0.000    0.000    0.000 controlflow.py:497(_find_dominance_frontier)
#         1    0.000    0.000    0.000    0.000 controlflow.py:500(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 controlflow.py:512(_find_dominators_internal)
#        26    0.000    0.000    0.000    0.000 controlflow.py:548(<listcomp>)
#         1    0.000    0.000    0.000    0.000 controlflow.py:555(_find_dominators)
#         1    0.000    0.000    0.000    0.000 controlflow.py:558(_find_post_dominators)
#        13    0.000    0.000    0.001    0.000 controlflow.py:579(_find_back_edges)
#        91    0.000    0.000    0.000    0.000 controlflow.py:602(push_state)
# ...
#       130    0.000    0.000    0.000    0.000 values.py:1064(align)
#       130    0.000    0.000    0.000    0.000 values.py:1073(dereferenceable)
#       130    0.000    0.000    0.000    0.000 values.py:1082(dereferenceable_or_null)
#       130    0.000    0.000    0.001    0.000 values.py:1091(_to_list)
#       130    0.010    0.000    0.014    0.000 values.py:1104(__init__)
#        24    0.000    0.000    0.000    0.000 values.py:1114(add_attribute)
#        95    0.000    0.000    0.016    0.000 values.py:1123(__str__)
#        35    0.000    0.000    0.000    0.000 values.py:1137(__str__)
#        79    0.000    0.000    0.023    0.000 values.py:1154(__init__)
#        79    0.000    0.000    0.000    0.000 values.py:1160(is_terminated)
#        32    0.000    0.000    0.000    0.000 values.py:1164(function)
#        79    0.000    0.000    0.058    0.001 values.py:1172(descr)
#        79    0.000    0.000    0.057    0.001 values.py:1174(<listcomp>)
#        79    0.000    0.000    0.000    0.000 values.py:1188(_format_name)
#        15    0.000    0.000    0.000    0.000 values.py:31(_escape_string)
#        11    0.000    0.000    0.000    0.000 values.py:342(bitcast)
#       358    0.001    0.000    0.002    0.000 values.py:445(__init__)
#        42    0.000    0.000    0.000    0.000 values.py:452(_to_string)
#   326/323    0.000    0.000    0.001    0.000 values.py:455(_get_reference)
#        15    0.000    0.000    0.000    0.000 values.py:47(<listcomp>)
#         1    0.000    0.000    0.000    0.000 values.py:484(literal_struct)
#         1    0.000    0.000    0.000    0.000 values.py:489(<listcomp>)
#        58    0.000    0.000    0.000    0.000 values.py:498(__eq__)
#        84    0.000    0.000    0.001    0.000 values.py:507(__hash__)
#        11    0.000    0.000    0.000    0.000 values.py:519(__init__)
#        11    0.000    0.000    0.000    0.000 values.py:526(_get_reference)
#      1074    0.002    0.000    0.034    0.000 values.py:537(__init__)
#       812    0.003    0.000    0.063    0.000 values.py:544(_to_string)
#      1057    0.004    0.000    0.004    0.000 values.py:554(_get_name)
#      1093    0.003    0.000    0.032    0.000 values.py:557(_set_name)
#       773    0.015    0.000    0.020    0.000 values.py:564(_get_reference)
#       228    0.000    0.000    0.000    0.000 values.py:575(function_type)
#        14    0.000    0.000    0.000    0.000 values.py:592(__init__)
#         5    0.000    0.000    0.000    0.000 values.py:601(_get_reference)
#        18    0.000    0.000    0.000    0.000 values.py:606(__eq__)
#        28    0.000    0.000    0.000    0.000 values.py:615(__hash__)
#         7    0.000    0.000    0.000    0.000 values.py:665(__init__)
#         7    0.000    0.000    0.000    0.000 values.py:672(descr)
#         7    0.000    0.000    0.000    0.000 values.py:685(_get_reference)
#        11    0.000    0.000    0.000    0.000 values.py:70(wrapped)
#        61    0.000    0.000    0.001    0.000 values.py:781(__init__)
#        26    0.003    0.000    0.006    0.000 values.py:794(__init__)
#        26    0.000    0.000    0.009    0.000 values.py:806(descr)
#       255    0.000    0.000    0.000    0.000 values.py:860(__init__)
#         2    0.000    0.000    0.000    0.000 values.py:867(_expand)
#        26    0.000    0.000    0.000    0.000 values.py:870(add)
#       132    0.000    0.000    0.000    0.000 values.py:875(_to_list)
#       132    0.000    0.000    0.000    0.000 values.py:876(<listcomp>)
#        35    0.003    0.000    0.003    0.000 values.py:890(__init__)
#        35    0.000    0.000    0.018    0.001 values.py:936(__init__)
#        35    0.000    0.000    0.013    0.000 values.py:943(<listcomp>)
#        66    0.000    0.000    0.000    0.000 values.py:949(module)
#        43    0.000    0.000    0.000    0.000 values.py:953(entry_basic_block)
#         1    0.000    0.000    0.000    0.000 values.py:957(basic_blocks)
#        79    0.000    0.000    0.023    0.000 values.py:961(append_basic_block)
#        35    0.001    0.000    0.017    0.000 values.py:973(descr_prototype)
#       130    0.000    0.000    0.016    0.000 values.py:979(<genexpr>)
#       105    0.000    0.000    0.000    0.000 values.py:989(<genexpr>)
#         3    0.000    0.000    0.058    0.019 values.py:999(descr_body)
#       144    0.000    0.000    0.001    0.000 warnings.py:165(simplefilter)
#       144    0.000    0.000    0.001    0.000 warnings.py:181(_add_filter)
#       144    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#       144    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#       144    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         1    0.000    0.000    0.000    0.000 weakref.py:134(__getitem__)
#         1    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#         1    0.000    0.000    0.000    0.000 weakref.py:348(__new__)
#         1    0.000    0.000    0.000    0.000 weakref.py:353(__init__)
#       421    0.001    0.000    0.023    0.000 weakref.py:415(__getitem__)
#         2    0.000    0.000    0.000    0.000 weakref.py:428(__setitem__)
#       277    0.005    0.000    0.005    0.000 {built-in method __new__ of type object at 0x57ea8dc4e9a0}
#      2167    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#       676    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        45    0.000    0.000    0.000    0.000 {built-in method _abc.get_cache_token}
#        28    0.000    0.000    0.000    0.000 {built-in method _ctypes.byref}
#         8    0.000    0.000    0.000    0.000 {built-in method _ctypes.sizeof}
#       151    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha1}
#        40    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        40    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.not_}
#        40    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        40    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       432    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_base64}
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#       117    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       296    0.000    0.000    0.001    0.000 {built-in method builtins.any}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.bin}
#        31    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#         1    0.000    0.000    0.849    0.849 {built-in method builtins.exec}
# 4696/4682    0.002    0.000    0.003    0.000 {built-in method builtins.getattr}
#      1367    0.004    0.000    0.004    0.000 {built-in method builtins.hasattr}
#  1234/979    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#      1432    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     44748    0.010    0.000    0.020    0.000 {built-in method builtins.isinstance}
#      2456    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#       568    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 5226/5098    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        33    0.000    0.000    0.000    0.000 {built-in method builtins.min}
# 2230/2078    0.002    0.000    0.095    0.000 {built-in method builtins.next}
#        53    0.000    0.000    0.000    0.000 {built-in method builtins.print}
# 2671/2619    0.001    0.000    0.003    0.000 {built-in method builtins.repr}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#       484    0.003    0.000    0.006    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 {built-in method numba._dynfunc.make_function}
#       155    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#        92    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        16    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         3    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#        28    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#        15    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#      1082    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {built-in method zlib.compressobj}
#         1    0.000    0.000    0.000    0.000 {function Pickler.dump at 0x7f4d6429eb90}
#       933    0.000    0.000    0.000    0.000 {function _TargetRegistry.__getitem__ at 0x7f4d40c9a710}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        69    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        40    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        12    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {method '_insert' of '_dispatcher.Dispatcher' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#       497    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#      2969    0.002    0.000    0.003    0.000 {method 'add' of 'set' objects}
#        53    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#      5789    0.005    0.000    0.005    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'center' of 'str' objects}
#       114    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        68    0.000    0.000    0.000    0.000 {method 'clear' of 'frame' objects}
#         7    0.000    0.000    0.000    0.000 {method 'clear' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         1    0.000    0.000    0.000    0.000 {method 'compress' of 'zlib.Compress' objects}
#      1364    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        22    0.000    0.000    0.000    0.000 {method 'copy' of 'set' objects}
#       282    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        14    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        51    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       152    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#      5591    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Compress' objects}
# 4965/2423    0.017    0.000    0.059    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#      2553    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#        21    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#        30    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         7    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#       755    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#       972    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        39    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#        43    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        27    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#        58    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       628    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
# 1823/1804    0.001    0.000    0.019    0.000 {method 'join' of 'str' objects}
#       132    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        27    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        79    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        30    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#       746    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       688    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        74    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       497    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       151    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        41    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        83    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#       812    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        58    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#      2329    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       163    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       154    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      2236    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        34    0.000    0.000    0.000    0.000 {method 'with_traceback' of 'BaseException' objects}
#      2742    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# ## Next Steps
#
# Congratulations on completing this advanced Numba tutorial for machine learning! You've gained valuable insights into optimizing Python code for high-performance machine learning tasks. To further enhance your skills and expand your knowledge, consider the following next steps:
#
# 1. **Practice and Experimentation**: Apply the techniques learned in this tutorial to your own machine learning projects. Experiment with different Numba optimizations and measure their impact on your specific use cases.
#
# 2. **Explore Advanced CUDA Programming**: If you're interested in GPU acceleration, delve deeper into CUDA programming with Numba. Learn about shared memory, atomic operations, and more complex parallel algorithms.
#
# 3. **Benchmark Against Other Solutions**: Compare Numba-optimized code with other high-performance computing solutions like Cython, Dask, or pure C/C++ implementations. Understand the trade-offs between development time and execution speed.
#
# 4. **Contribute to Open Source**: Many machine learning libraries could benefit from Numba optimizations. Consider contributing to open-source projects by optimizing computationally intensive parts of their codebase.
#
# 5. **Stay Updated**: Numba is continuously evolving. Keep an eye on the official Numba documentation and release notes for new features and improvements.
#
# 6. **Explore Integration with ML Frameworks**: Investigate how Numba can be integrated with popular machine learning frameworks like scikit-learn, PyTorch, or TensorFlow for custom operations.
#
# 7. **Attend Conferences and Workshops**: Participate in conferences or workshops focused on high-performance computing in Python to learn from experts and share your experiences.
#
# 8. **Optimize Full ML Pipelines**: Apply Numba optimizations to entire machine learning pipelines, from data preprocessing to model evaluation, to achieve end-to-end performance improvements.
#
# 9. **Learn About Memory Management**: Dive deeper into memory management techniques in Numba to handle large datasets efficiently and avoid common pitfalls.
#
# 10. **Explore Multi-GPU Programming**: If you have access to multiple GPUs, learn how to distribute computations across them using Numba and CUDA.
#
# Remember, becoming proficient in high-performance computing for machine learning is an ongoing journey. Continuous practice and staying curious about new developments in the field will help you become a more effective and efficient machine learning researcher or practitioner.
#
# Happy coding, and may your models train faster than ever before!

# %% [markdown]
# ## Conclusion
#
# This tutorial covered advanced Numba techniques for machine learning researchers, including parallel processing, custom data types, GPU acceleration, and profiling. By leveraging these features, you can significantly speed up your machine learning algorithms and handle larger datasets more efficiently.
#
# Remember to always profile your code and compare it with non-Numba implementations to ensure you're getting the expected performance improvements. Happy coding!
